# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(0)

def gen_sample_grid(npx=200, npy=200, limit = 4):
  x1line = np.linspace(-limit, limit, npx)
  x2line = np.linspace(-limit, limit, npy)
  x1grid, x2grid = np.meshgrid(x1line, x2line)
  Xgrid = np.array([x1grid, x2grid]).reshape([2,npx*npy]).T
  return Xgrid, x1line, x2line

Xgrid, x1line, x2line = gen_sample_grid()

from sklearn import datasets

X, y = datasets.make_classification(n_samples=100,n_features=2,n_informative=2,n_redundant=0)

from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf.fit(X,y)
Xgrid = clf.predict(Xgrid)

#### ask if this is the correct clasfication
Xgrid = np.reshape(Xgrid,[200,200])

plt.contourf(x1line,x2line,Xgrid)
plt.scatter(X[y==0,0],X[y==0,1])
plt.scatter(X[y==1,0],X[y==1,1])
